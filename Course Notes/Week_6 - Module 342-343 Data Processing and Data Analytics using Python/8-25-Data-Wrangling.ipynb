# %% [markdown]
# # Data Wrangling 08-25-2023

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Agenda:
#
# Time 	Activity	Activity Details
# Morning
# SBA Discussion... no actual code please ;)
# Tek@ PD
# Secrets controversy
# secrets.py vs creds.py
# Valerie's 3 video playlist on the concept of storing secrets aka any data that you don't want others to access through shared version control systems (like git) but you want to include in your code still! - https://youtube.com/playlist?Links to an external site.
# list=PLcyJ9GAggX_k3hrqNB_4Lv3_TcFWqbrlg&feature=sharedLinks to an external site.
# TL;DR:  Use dot_envLinks to an external site.
# Quiz Gameshow review of 343.1 Pandas Basics
# image.png
# Resources: Valerie's favorite Pandas playlist: https://www.youtube.com/playlist?list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDSLinks to an external site.
#
#
#
#
# ELINK - 343.2 - Data Wrangling (Week 2)
# 343.3.1 - working with missing data
#
#
#
#
#
#
# 12pm-1pm
# Lunch
#
# Afternoon
# Working with Missing Values
#
#
#
# 4pm -5 pm
# Office hours W Ben and Aikerim
#
#
#
#
#
#
#
# Python Pandas Tutorial Corey Schafer - https://youtube.com/playlist?list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&feature=shared
#
# Check the Learners Share Drive for my sample file!
#
# Data PreProcessing tools in Pandas
# 2023.08.22 vlb
#
# *Learning Objectives:**
# - Describe how to handle missing values
# - Describe data formatting techniques
# - Describe data normalization
# - Demonstrate the use of binning
# - Demonstrate the use of categorical variables
# **Resources:**
#
# https://www.coursera.org/learn/data-analysis-with-python/home/week/2Links to an external site.
# Lab in Canvas
# Valerie’s Favorite Pandas Playlist: https://youtube.com/playlist?list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&feature=sharedLinks to an external site.
# Official Documentation: https://pandas.pydata.org/docs/user_guide/index.htmlLinks to an external site.
#
# Remember! Clean data is good data.  So wash yer data!
#
#
#
# **Handling Missing Values:**
# - `isna()`: Returns a DataFrame of boolean values indicating missing values.
# - `fillna()`: Fills missing values with specified values or strategies.
# - `dropna()`: Removes rows or columns with missing values.
# - `interpolate()`: Interpolates missing values using various methods.
# - `replace()`: Replaces specific values, including missing values, with specified values.
#
# **Data Formatting Techniques:**
# - `str.upper()`, `str.lower()`: Converts string data to uppercase or lowercase.
# - `str.strip()`: Removes leading and trailing whitespaces from string data.
# - `str.replace()`: Replaces specific substrings in string data.
# - `astype()`: Converts data types of columns to specified data types.
# - `applymap()`: Applies a function element-wise to all elements of a DataFrame.
#
# **Data Normalization:**
# - Simple Feature Scaling: Dividing data by the maximum value.
# - Min-Max Scaling: Subtracting minimum and dividing by the range.
# - Z-Score Normalization: Subtracting mean and dividing by standard deviation.
# - `mean()`: Calculates mean of columns or rows.
# - `std()`: Calculates standard deviation of columns or rows.
#
# **Binning:**
# - `cut()`: Bins data into discrete intervals or categories.
# - `qcut()`: Bins data into quantiles.
# - `pd.Series.value_counts()`: Counts the occurrences of unique values, useful for binning based on frequency.
# - `groupby()`: Groups data for further analysis, similar to binning for aggregation.
#
# **Categorical Variables:**
# - `pd.get_dummies()`: Converts categorical variables into dummy/indicator variables.
# - `astype('category')`: Converts a column to a categorical data type.
# - `Categorical()` constructor: Creates a categorical data type for a column with specified categories.
# - `groupby()`: Groups data by categorical variables for aggregation.
# - `pd.Categorical.value_counts()`: Counts the occurrences of unique categories.
