# %% [markdown]
# # CSV Review, APIs, Request Library and SWAPI

# %% [markdown]
# Friday, August 18, 2023 Agenda - CSV Review, APIs, Request Library and SWAPI
# Aikerim Daniiar Kyzy
# All Sections
# No unread replies.No replies.
# The class starts at 9:00 am (MT) please don't be late.
#
# Platform: Zoom
#
# Join URL: https://perscholas.zoom.us/j/93004660299?pwd=RlUvQVN1TjJTMExYRFNTYXI5NURtdz09Links to an external site.
#
#
#
# Agenda:
#
# Time 	Activity	Activity Details
# Morning
#
# Lesson 342.2 - ELINK - Read JSON with Python
# https://realpython.com/api-integration-in-python/Links to an external site.
# ACT 342.2.1 - Advanced Python - Cumulative Lab1
#
#
# Topics:
#
# 5 Q Gameshow Poll
#
# Review csv 20-30 min (look for learner drive file)
#
# Revisit JSON in depth with examples. (an hour?)
#
# Learn about API's (30 min)
#
# Learn the Request Library (30 min)
#
# SWAPI - May the Force be with us! The rest of the day!
#
# Resources:
#
# #### Extra Resources:
# https://www.w3schools.com/python/python_json.aspLinks to an external site. has practice blocks!
# https://www.datacamp.com/tutorial/json-data-pythonLinks to an external site. has workspace!
# https://www.realpythonproject.com/a-cheat-sheet-for-working-with-json-data-in-python/
# Valerie's API Playlist: https://bit.ly/3DZlaaY
#
# Really Good:
# https://developer.mozilla.org/en-US/docs/Learn/JavaScript/Objects/JSONLinks to an external site.
# https://www.techiedelight.com/json-introduction/Links to an external site.
#  - Good!
# https://techiedelight.com/tools/jsonLinks to an external site. a visualizer
#
# https://realpython.com/python-requests/Links to an external site.
# 12pm-1pm
# Lunch
#
# Afternoon
# ACT 342.2.2 - Advanced Python - Cumulative Lab2
# ACT 342.2.3 - Advanced Python - Cumulative Lab3
# Questions and Practice
#
#
# 4pm -5 pm
# Office hours W Ben
#
#
#
# This announcement is closed for comments
# This topic was edited by Valerie Boss (She/Her)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 342.2 Connect and Parsing + REST APIs

# %% [markdown]
# Monday, August 21, 2023 Agenda - 342.2 Connect and Parsing + REST APIs
# Aikerim Daniiar Kyzy
# All Sections
# No unread replies.No replies.
# The class starts at 9:00 am (MT) please don't be late.
#
# Platform: Zoom
#
# Join URL: https://perscholas.zoom.us/j/93004660299?pwd=RlUvQVN1TjJTMExYRFNTYXI5NURtdz09Links to an external site.
#
#
#
# Agenda:
#
# Morning, :
#
# Discussion on Data collection, data structures, etc.
# REST APis  Discussion
# Video walkthrough - Rick and Morty API examples
# Act342.2.1 Finish up SWAPI Exercise
#
#
# Review these from the Previous Week
#
# Lesson 342.1 - Read and Write Data to Files
# Module 342 - Lesson 2
# Lessons	Assignments
# Lesson 342.2 - ELINK - Read JSON with Python From Last WeekLinks to an external site.	ACT 342.2.1 - Advanced Python - Cumulative Lab1
# Lesson 352.6 - ELINK - Python and REST APIsLinks to an external site. from last week	ACT 342.2.2 - Advanced Python - Cumulative Lab2
# ACT 342.2.3 - Advanced Python - Cumulative Lab3
#
#
# Afternoon
#
# Labs/Activities  342.2.2 and 342.2.2
# possibly Lesson 342.5 - ELINK - Parsing XML DataLinks to an external site.
# Office Hours:  JSON/REST API review/questions with Ben
#
# NOTE: Any grade less than a 70 on the assessment necessitates mandatory attendance and participation during office hours!
# This announcement is closed for comments
# This topic was edited by Valerie Boss (She/Her)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.geeksforgeeks.org/serialize-and-deserialize-complex-json-in-python/
#
# https://janakiev.com/blog/python-json/

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import json

# Writing a JSON file
with open('data.json', 'w') as f:
    json.dump(data, f)

# Reading a JSON file
with open('data.json', 'r') as f:
    data = json.load(f)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
json_string = json.dumps(data)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = json.loads(json_string)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://docs.python.org/3/library/json.html

# %%
import json
json.dumps(['foo', {'bar': ('baz', None, 1.0, 2)}])
'["foo", {"bar": ["baz", null, 1.0, 2]}]'
print(json.dumps("\"foo\bar"))
"\"foo\bar"
print(json.dumps('\u1234'))
"\u1234"
print(json.dumps('\\'))
"\\"
print(json.dumps({"c": 0, "b": 0, "a": 0}, sort_keys=True))
{"a": 0, "b": 0, "c": 0}
from io import StringIO
io = StringIO()
json.dump(['streaming API'], io)
io.getvalue()
'["streaming API"]'
# Out:
# "\"foo\bar"
# "\u1234"
# "\\"
# {"a": 0, "b": 0, "c": 0}
# '["streaming API"]'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(data[0]['hobbies'][0])
# This code accesses the first element of the data list, then accesses the 'hobbies' key within that dictionary, and finally prints the first element of the hobbies list using [0].
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(data[0]['hobbies'][0])
#       2 # This code accesses the first element of the data list, then accesses the 'hobbies' key within that dictionary, and finally prints the first element of the hobbies list using [0].
#
# NameError: name 'data' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://json-generator.com/#generate

# %% [markdown]
# ## Requests Library
