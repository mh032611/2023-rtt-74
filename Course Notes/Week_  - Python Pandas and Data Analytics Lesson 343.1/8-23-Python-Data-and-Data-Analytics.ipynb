# %% [markdown]
# # Python-Data-and-Data-Analytics 08-23-2023

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [raw]
# Wednesday, August 23 - Python Pandas and Data Analytics
# Aikerim Daniiar Kyzy
# All Sections
# No unread replies.No replies.
# The class starts at 9:00 am (MT) please don't be late.
#
# Platform: Zoom
#
# Join URL: https://perscholas.zoom.us/j/93004660299?pwd=RlUvQVN1TjJTMExYRFNTYXI5NURtdz09Links to an external site.
#
#
#
# Agenda:
#
# Time 	Activity	Activity Details
# Morning
#
# Lesson 343.1 - Python Pandas and Data Analytics
# Resources:
#
#
#
# 12pm-1pm
# Lunch
#
# Afternoon
# ELINK - 343.1 - Importing Datasets https://www.coursera.org/learn/data-analysis-with-python
# GLAB - 343.1.1 - Panda Series
# GLAB - 343.1.2 - Creating a pandas DataFrame

# %% [raw]
# Pandas Cheat Sheets
# https://www.datacamp.com/cheat-sheet/pandas-cheat-sheet-for-data-science-in-python
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
# https://www.datacamp.com/cheat-sheet/pandas-cheat-sheet-for-data-science-in-python
# https://www.geeksforgeeks.org/pandas-cheat-sheet/
# https://www.webpages.uidaho.edu/~stevel/cheatsheets/Pandas%20DataFrame%20Notes_12 Ges.pdf
#
#
# Data Wrangling in Pandas
# https://www.geeksforgeeks.org/data-wrangling-in-python
#
# https://pandas.pydata.org/docs/user_guide/10min.html#min
# https://pandas.pydata.org/docs/getting_started/index.html
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/index.html

# %%
# pip install numpy
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.0.3-cp310-cp310-win_amd64.whl (10.7 MB)
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Guided Lab - 343.1 - Panda Series

# %% [markdown]
# Example 1: Creating Panda Series from Dictionary

# %%
import pandas as pd
d = {"b": 1, "a": 0, "c": 2}
pd.Series(d)

#the use of quotes around index labels in Pandas Series creation helps distinguish them as string values and ensures that they are interpreted as labels rather than variable names or other values.
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %%
import pandas as pd
d = {"a": 0.0, "b": 1.0, "c": 2.0}
pd.Series(d)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
pd.Series(d, index=["b", "c", "d", "a"])
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %% [markdown]
# Example 2: Key/Value Objects as Series

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)

# Note: The keys of the dictionary become the labels.
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# Example 2.2
#
# To select only some of the items in the dictionary, use the index argument and specify only the items you want to include in the Series.
#
# Create a Series using only data from "day1" and "day2":

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories, index = ["day1", "day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# Example 3:  Creating Panda Series from Scalar Value
#
#
# If data is a scalar value, an index must be provided. The value will be repeated to match the length of the index.

# %%
pd.Series(5.0, index=["a", "b", "c", "d", "e"])
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# dtype: float64

# %% [markdown]
# ## Guided Lab - 343.1.2 Creating a Pandas DataFrame

# %% [markdown]
# Example 1: Creating a Pandas DataFrame With Dictionaries

# %% [markdown]
# We can create a Pandas DataFrame with a Python dictionary:

# %%
import numpy as np
import pandas as pd


d = {'x': [1, 2, 3], 'y': np.array([2, 4, 8]), 'z': 100}
pd.DataFrame(d)
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
pd.DataFrame(d, index=[100, 200, 300], columns=['z', 'y', 'x'])
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %% [markdown]
# Example 2: Creating a Pandas DataFrame With Lists
#
# Another way to create a Pandas DataFrame is to use a list of dictionaries:

# %%
l = [{'x': 1, 'y': 2, 'z': 100},
     {'x': 2, 'y': 4, 'z': 100},
     {'x': 3, 'y': 8, 'z': 100}]

pd.DataFrame(l)
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %% [markdown]
# Again, the dictionary keys are the column labels, and the dictionary values are the data values in the DataFrame.
#
# You can also use a nested list, or a list of lists, as the data values. If you do, then it is wise to explicitly specify the labels of columns, rows, or both when you create the DataFrame.

# %%
l = [[1, 2, 100],
     [2, 4, 100],
     [3, 8, 100]]

pd.DataFrame(l, columns=['x', 'y', 'z'])
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %% [markdown]
# Example 3: Creating a pandas DataFrame With NumPy Arrays

# %%
arr = np.array([[1, 2, 100],[2, 4, 100],[3, 8, 100]])
df = pd.DataFrame(arr, columns=['x', 'y', 'z'])
df
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
arr[0, 0] = 1000
df
# Out:
#       x  y    z
# 0  1000  2  100
# 1     2  4  100
# 2     3  8  100

# %% [markdown]
# ## GLAB 343.3.2 Read CSV into Panda DataFrame

# %%
import numpy
